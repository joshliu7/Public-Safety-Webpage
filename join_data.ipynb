# %%
import pandas as pd

# %%
crime = pd.read_csv("crime2021_filtered.csv")
three11 = pd.read_csv("3112021_filtered.csv")

# %%
crime
# Out:
#       Unnamed: 0  INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0            221        212073579          3803                 NaN
# 1            282        212073487          3410                 NaN
# 2            323        212073439          3005                 NaN
# 3            398        212073321           801                 NaN
# 4            429        212073269          2905                 NaN
# ...          ...              ...           ...                 ...
# 1169       55277        212000130          3115                 NaN
# 1170       55405        210270252          3005                 NaN
# 1171       55423        210152351          2610                 NaN
# 1172       55434        210096279          3115                 NaN
# 1173       55477         10637224          3125                 NaN
#
#                                             Description DISTRICT  \
# 0                        M/V ACCIDENT - PERSONAL INJURY       D4
# ...

# %%
three11
# Out:
#       Unnamed: 0  case_enquiry_id              open_dt            target_dt  \
# 0             34     101003578949  2021-01-01 08:36:00  2021-01-05 08:30:00
# 1             66     101003579174  2021-01-01 12:36:00  2021-05-01 12:36:45
# 2             72     101003579226  2021-01-01 13:27:00  2021-01-05 08:30:00
# 3            104     101003578997  2021-01-01 09:41:00  2021-01-05 08:30:00
# 4            197     101003579937  2021-01-02 19:40:30  2021-01-07 08:30:00
# ...          ...              ...                  ...                  ...
# 4257      229764     101004018299  2021-10-21 10:53:34  2021-10-25 10:53:34
# 4258      229940     101004020243  2021-10-22 14:23:27  2021-10-27 14:23:27
# 4259      230036     101004021447  2021-10-23 20:56:16                  NaN
# 4260      230048     101004021585  2021-10-24 08:18:55  2021-10-26 08:30:00
# 4261      230113     101004022503  2021-10-25 10:52:00  2021-10-26 10:52:30
#
#                 closed_dt   ontime case_status  \
# ...

# %%
needle = three11[three11['type'] == 'Needle Pickup']
needle
# Out:
#       Unnamed: 0  case_enquiry_id              open_dt target_dt  \
# 8            330     101003580441  2021-01-04 05:04:29       NaN
# 16           661     101003581782  2021-01-05 12:08:19       NaN
# 22          1170     101003585396  2021-01-10 10:37:16       NaN
# 26          1400     101003587969  2021-01-13 08:15:04       NaN
# 27          1459     101003583635  2021-01-07 14:39:56       NaN
# ...          ...              ...                  ...       ...
# 4224      228208     101003998575  2021-10-05 23:44:27       NaN
# 4225      228253     101003999123  2021-10-06 10:38:00       NaN
# 4248      229240     101004011690  2021-10-16 11:49:45       NaN
# 4251      229264     101004011978  2021-10-16 16:27:08       NaN
# 4259      230036     101004021447  2021-10-23 20:56:16       NaN
#
#                 closed_dt  ontime case_status  \
# 8     2021-01-04 06:53:51  ONTIME      Closed
# 16    2021-01-05 12:42:00  ONTIME      Closed
# ...

# %%
crime = crime.rename(columns={"OFFENSE_DESCRIPTION": "Description"})

# %%
needle = needle.rename(columns={"type": "Description"})

# %%
expected_length = len(crime) + len(needle)
joined = crime.append(needle)
len(joined) == expected_length
# Out:
# True

# %%
joined
# Out:
#       Unnamed: 0  INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0            221      212073579.0        3803.0                 NaN
# 1            282      212073487.0        3410.0                 NaN
# 2            323      212073439.0        3005.0                 NaN
# 3            398      212073321.0         801.0                 NaN
# 4            429      212073269.0        2905.0                 NaN
# ...          ...              ...           ...                 ...
# 4224      228208              NaN           NaN                 NaN
# 4225      228253              NaN           NaN                 NaN
# 4248      229240              NaN           NaN                 NaN
# 4251      229264              NaN           NaN                 NaN
# 4259      230036              NaN           NaN                 NaN
#
#                          Description DISTRICT REPORTING_AREA  SHOOTING  \
# 0     M/V ACCIDENT - PERSONAL INJURY       D4                      0.0
# ...

# %%
joined.convert_dtypes().to_csv('data.csv')
